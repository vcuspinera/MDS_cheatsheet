# %% [markdown]
# ## Time complexity for different models

# %%
from IPython.display import Image
Image("imgs/571_B3_models-time-complexity.jpg")

# %% [markdown]
# ## Bias Variance Trade-off

# %%
Image("imgs/571_B3_bias-variance-accuracy-precision.jpg")
